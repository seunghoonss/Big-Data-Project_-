# %%
import pandas as pd
df = pd.read_excel('경상남도 창원시_병원(부속의료기관, 의원) 현황.xlsx')

# %%
df = pd.read_excel('병원정보_최신화.xlsx')

# %%
from sklearn.datasets import make_blobs
import pandas as pd
import numpy as np
import math
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt


# In[5]:


get_ipython().system('pip install openpyxl')


# In[6]:


df = pd.read_excel('병원정보_최신화.xlsx')

# In[11]:


df = df.iloc[:, 6:8]


# In[16]:


from sklearn.cluster import KMeans 

# k-means clustering 실행
kmeans = KMeans(n_clusters=5)
kmeans.fit(df)

# 결과 확인
result_by_sklearn = df.copy()
result_by_sklearn["cluster"] = kmeans.labels_
result_by_sklearn.head()


# In[17]:


sns.scatterplot(x="YPos", y="XPos", hue="cluster", data=result_by_sklearn, palette="Set2");
# Out:
# Requirement already satisfied: openpyxl in c:\users\sshss\anaconda3\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\sshss\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# 랜덤값 고정
#np.random.seed(8)
#X, y = make_blobs(n_samples=1000, centers=4, cluster_std=0.9)
#plt.scatter(X[:, 0], X[:, 1], marker='.')


# In[5]:


get_ipython().system('pip install openpyxl')


# In[6]:


df = pd.read_excel('병원정보_최신화.xlsx')

# In[11]:


df = df.iloc[:, 6:8]



k_means = KMeans(init="k-means++", n_clusters=5, n_init=20)
k_means.fit(X)

k_means_labels = k_means.labels_
print('k_means_labels : ', k_means_labels)

k_means_cluster_centers = k_means.cluster_centers_
print('k_means_cluster_centers : ', k_means_cluster_centers)

# 지정된 크기로 초기화
fig = plt.figure(figsize=(6, 4))

# 레이블 수에 따라 색상 배열 생성, 고유한 색상을 얻기 위해 set(k_means_labels) 설정
colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means_labels))))

# plot 생성
ax = fig.add_subplot(1, 1, 1)

for k, col in zip(range(5), colors):
    my_members = (k_means_labels == k)

    # 중심 정의
    cluster_center = k_means_cluster_centers[k]

    # 중심 그리기
    ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.')
    ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col, markeredgecolor='k', markersize=6)

ax.set_title('K-Means')
ax.set_xticks(())
ax.set_yticks(())
plt.show()
# Out:
# Requirement already satisfied: openpyxl in c:\users\sshss\anaconda3\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\sshss\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# k_means_labels :  [1 2 3 0 1 4 3 0 3 0 0 4 1 3 2 3 2 2 4 2 1 1 1 0 3 3 0 4 0 2 3 2 4 2 1 1 1
#  1 0 0 0 4 4 3 4 0 3 0 3 2 2 3 4 4 0 2 3 0 3 0 3 3 3 3 3 2 0 2 2 2 2 4 2 0
#  3 3 3 3 2 3 1 4 3 0 2 3 3 2 0 4 4 2 1 2 2 0 3 0 4 3 0 3 2 2 1 0 2 2 0 2 0
#  0 2 4 2 3 1 3 3 2 3 0 1 0 3 3 1 0 4 2 2 4 3 0 3 2 3 2 0 4 4 1 0 0 3 3 1 1
#  3 2 2 3 3 0 0 3 1 0 0 2 0 3 4 1 3 3 2 1 2 0 3 3 1 0 4 0 4 2 3 2 3 0 1 3 3
#  3 1 3 2 0 2 3 0 1 3 0 3 0 3 2 2 0 3 2 2 2 3 3 0 0 3 0 0 2 4 0 4 2 2 0 2 2
#  1 2 3 0 1 2 1 0 0 0 3 3 4 3 4 0 2 1 3 2 0 0 1 3 3 0 0 2 2 3 2 3 0 0 4 0 3
#  2 2 3 2 0 3 3 3 3 4 0 4 4 2 3 3 0 2 2 0 3 0 0 2 3 0 0 0 2 0 2 4 0 2 1 3 1
